# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
import json

# API Key
from config import gkey

# %%
# Import cities info from csv
cities_df = pd.read_csv("../Resources/KC_Metro_Cities.csv")
cities_df.head()
# Out:
#          Cities     State
# 0        Belton  Missouri
# 1       Gardner    Kansas
# 2     Gladstone  Missouri
# 3     Grandview  Missouri
# 4  Independence  Missouri

# %%
# add columns for restaurant name, restaurant address, rating
cities_df["Latitude"]=""
cities_df["Longitude"]=""
cities_df["Place Name"]=""
cities_df["Place Address"]=""
cities_df["Place Rating"]=""
cities_df["Place Latitude"]=""
cities_df["Place Longitude"]=""
cities_df.head()
# Out:
#          Cities     State Latitude Longitude Place Name Place Address  \
# 0        Belton  Missouri
# 1       Gardner    Kansas
# 2     Gladstone  Missouri
# 3     Grandview  Missouri
# 4  Independence  Missouri
#
#   Place Rating Place Latitude Place Longitude
# 0
# 1
# 2
# 3
# 4

# %%
# create params dictionary to be updated with new city each iteration
params = {"key": gkey}

# loop through cities_df and run lat/lon search for each city
for index, row in cities_df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    
    city = row["Cities"]
    state = row["State"]
    
    # update address key value
    params["address"] = f"{city},{state}"
    
    # make request
    cities_lat_lon = requests.get(base_url, params=params)
#     print(cities_lat_lon.url)
    
    # convert to json
    cities_lat_lon = cities_lat_lon.json()
    
    cities_df.loc[index, "Latitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lat"]
    cities_df.loc[index, "Longitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lng"]

#visualize to confirm
cities_df.head()
# Out:
#          Cities     State Latitude Longitude Place Name Place Address  \
# 0        Belton  Missouri   38.812  -94.5319
# 1       Gardner    Kansas  38.8108  -94.9272
# 2     Gladstone  Missouri  39.2039  -94.5547
# 3     Grandview  Missouri  38.8858   -94.533
# 4  Independence  Missouri  39.0911  -94.4155
#
#   Place Rating Place Latitude Place Longitude
# 0
# 1
# 2
# 3
# 4

# %%
# params dictionary to update each iteration
params = {
    "radius": 15000,
    "types": "restaurant",
    "keyword": "mexican",
    "key": gkey
}
k=1
# use latitude/longitude to identify chinese retaurants
for index, row in cities_df.iterrows():
#     print(index)
#     get lat/lon from df
    lat = row["Latitude"]
    lon = row["Longitude"]
    
#     change location each iteration while 
#     leaving original params in place
    params["location"] = f"{lat},{lon}"
    
#     use the serach term "Chines Restaurant" and lat/lon
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
#     make request and print url
    response = requests.get(base_url, params=params)
    
#     print(response.url)

#     convert to json
    response = response.json()
#     print(json.dumps(response, indent=4, sort_keys=True))

#     since some data may be missing, use try/except to skip any missing
#     data point
#     loop through to gather 5 indices
    pkey= []
    city_name = []
    state_name = []
    city_lat = []
    city_lon = []
    name = []
    address = []
    rating = []
    place_lat = []
    place_lon = []
    i = 0
    for responses in response:
        while i < 5:
            try:
                pkey.append(k)
                city_name.append(row["Cities"])
                state_name.append(row["State"])
                city_lat.append(lat)
                city_lon.append(lon)
                name.append(response["results"][i]["name"])
                address.append(response["results"][i]["vicinity"])
                rating.append(response["results"][i]["rating"])
                place_lat.append(response["results"][i]["geometry"]["location"]["lat"])
                place_lon.append(response["results"][i]["geometry"]["location"]["lng"])
            except (KeyError, IndexError):
                print("Missing field/result... skipping.")
        
            i+=1
            k+=1
#     if index = 0 create a new dataframe        
    if index == 0:
        mexican_restaurant_df = pd.DataFrame({"ID":pkey, "City":city_name,
                                             "State":state_name,
                                             "Latitude":city_lat,
                                             "Longitude":city_lon,
                                             "Place Name":name,
                                             "Place Address":address,
                                             "Place Rating":rating,
                                             "Place Latitude":place_lat,
                                             "Place Longitude":place_lon})
# otherwise create a new dataframe and then append the new dataframe to [0] df
    else:
        other_mexican_df = pd.DataFrame({"ID":pkey, "City":city_name,
                                        "State":state_name,
                                        "Latitude":city_lat,
                                        "Longitude":city_lon,
                                        "Place Name":name,
                                        "Place Address":address,
                                        "Place Rating":rating,
                                        "Place Latitude":place_lat,
                                        "Place Longitude":place_lon})
        mexican_restaurant_df = mexican_restaurant_df.append(other_mexican_df).reset_index(drop=True)

# %%
mexican_restaurant_df
# Out:
#     ID               City     State   Latitude  Longitude  \
# 0    1             Belton  Missouri  38.811953 -94.531898
# 1    2             Belton  Missouri  38.811953 -94.531898
# 2    3             Belton  Missouri  38.811953 -94.531898
# 3    4             Belton  Missouri  38.811953 -94.531898
# 4    5             Belton  Missouri  38.811953 -94.531898
# 5    6            Gardner    Kansas  38.810841 -94.927187
# 6    7            Gardner    Kansas  38.810841 -94.927187
# 7    8            Gardner    Kansas  38.810841 -94.927187
# 8    9            Gardner    Kansas  38.810841 -94.927187
# 9   10            Gardner    Kansas  38.810841 -94.927187
# 10  11          Gladstone  Missouri  39.203892 -94.554677
# 11  12          Gladstone  Missouri  39.203892 -94.554677
# 12  13          Gladstone  Missouri  39.203892 -94.554677
# 13  14          Gladstone  Missouri  39.203892 -94.554677
# 14  15          Gladstone  Missouri  39.203892 -94.554677
# 15  16          Grandview  Missouri  38.885841 -94.533010
# 16  17          Grandview  Missouri  38.885841 -94.533010
# 17  18          Grandview  Missouri  38.885841 -94.533010
# 18  19          Grandview  Missouri  38.885841 -94.533010
# 19  20          Grandview  Missouri  38.885841 -94.533010
# 20  21       Independence  Missouri  39.091116 -94.415507
# 21  22       Independence  Missouri  39.091116 -94.415507
# 22  23       Independence  Missouri  39.091116 -94.415507
# 23  24       Independence  Missouri  39.091116 -94.415507
# 24  25       Independence  Missouri  39.091116 -94.415507
# 25  26        Kansas City    Kansas  39.115531 -94.626787
# 26  27        Kansas City    Kansas  39.115531 -94.626787
# 27  28        Kansas City    Kansas  39.115531 -94.626787
# 28  29        Kansas City    Kansas  39.115531 -94.626787
# 29  30        Kansas City    Kansas  39.115531 -94.626787
# ..  ..                ...       ...        ...        ...
# 65  66  North Kansas City  Missouri  39.142908 -94.572978
# 66  67  North Kansas City  Missouri  39.142908 -94.572978
# 67  68  North Kansas City  Missouri  39.142908 -94.572978
# 68  69  North Kansas City  Missouri  39.142908 -94.572978
# 69  70  North Kansas City  Missouri  39.142908 -94.572978
# 70  71             Olathe    Kansas  38.881396 -94.819128
# 71  72             Olathe    Kansas  38.881396 -94.819128
# 72  73             Olathe    Kansas  38.881396 -94.819128
# 73  74             Olathe    Kansas  38.881396 -94.819128
# 74  75             Olathe    Kansas  38.881396 -94.819128
# 75  76      Overland Park    Kansas  38.982228 -94.670792
# 76  77      Overland Park    Kansas  38.982228 -94.670792
# 77  78      Overland Park    Kansas  38.982228 -94.670792
# 78  79      Overland Park    Kansas  38.982228 -94.670792
# 79  80      Overland Park    Kansas  38.982228 -94.670792
# 80  81    Prairie Village    Kansas  38.991673 -94.633568
# 81  82    Prairie Village    Kansas  38.991673 -94.633568
# 82  83    Prairie Village    Kansas  38.991673 -94.633568
# 83  84    Prairie Village    Kansas  38.991673 -94.633568
# 84  85    Prairie Village    Kansas  38.991673 -94.633568
# 85  86            Raytown  Missouri  39.008617 -94.463564
# 86  87            Raytown  Missouri  39.008617 -94.463564
# 87  88            Raytown  Missouri  39.008617 -94.463564
# 88  89            Raytown  Missouri  39.008617 -94.463564
# 89  90            Raytown  Missouri  39.008617 -94.463564
# 90  91            Shawnee    Kansas  39.022848 -94.715187
# 91  92            Shawnee    Kansas  39.022848 -94.715187
# 92  93            Shawnee    Kansas  39.022848 -94.715187
# 93  94            Shawnee    Kansas  39.022848 -94.715187
# 94  95            Shawnee    Kansas  39.022848 -94.715187
#
#                
5708 N Oak Trafficway, Kansas City           4.3       39.198249
# 21               79 US-69, Kansas City           4.3       39.197061
# 22     207 Southwest Blvd, Kansas City           4.3       39.089028
# 23  7013 N Oak Trafficway, Kansas City           4.3       39.222086
# 24         2512 Holmes St, Kansas City           4.1       39.081007
# 25        2502 NW Vivion Rd, Northmoor           4.6       39.179828
# 26     4125 N Mulberry Dr, Kansas City           4.1       39.169509
# 27  5708 N Oak Trafficway, Kansas City           4.3       39.198249
# 28  7013 N Oak Trafficway, Kansas City           4.3       39.222086
# 29   5918 NW 63rd Terrace, Kansas City           4.3       39.209164
# ..                                 ...           ...             ...
# 65        2502 NW Vivion Rd, Northmoor           4.6       39.179828
# 66     4125 N Mulberry Dr, Kansas City           4.1       39.169509
# 67  5708 N Oak Trafficway, Kansas City           4.3       39.198249
# 68  7013 N Oak Trafficway, Kansas City           4.3       39.222086
# 69   5918 NW 63rd Terrace, Kansas City           4.3       39.209164
# 70    11741 Metcalf Ave, Overland Park           4.4       38.914466
# 71             7779 Quivira Rd, Lenexa           4.4       38.987058
# 72          2034 E Santa Fe St, Olathe           4.8       38.885086
# 73     9129 Elmhurst Dr, Overland Park           4.4       38.971941
# 74       8841 W 75th St, Overland Park           4.2       38.992454
# 75     207 Southwest Blvd, Kansas City           4.3       39.089028
# 76         2512 Holmes St, Kansas City           4.1       39.081007
# 77      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 78    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 79         2610 State Ave, Kansas City           4.1       39.117097
# 80     207 Southwest Blvd, Kansas City           4.3       39.089028
# 81         2512 Holmes St, Kansas City           4.1       39.081007
# 82      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 83         2610 State Ave, Kansas City           4.1       39.117097
# 84    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 85     207 Southwest Blvd, Kansas City           4.3       39.089028
# 86         2512 Holmes St, Kansas City           4.1       39.081007
# 87      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 88    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 89         901 Kansas Ave, Kansas City           4.6       39.087198
# 90     207 Southwest Blvd, Kansas City           4.3       39.089028
# 91      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 92         2610 State Ave, Kansas City           4.1       39.117097
# 93    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 94         2512 Holmes St, Kansas City           4.1       39.081007
#
#     Place Longitude
# 0        -94.380168
# 1        -94.667358
# 2        -94.536494
# 3        -94.585509
# 4        -94.377841
# 5        -94.780556
# 6        -94.789541
# 7        -94.797751
# 8        -94.815382
# 9        -94.761590
# 10       -94.609596
# 11       -94.597264
# 12       -94.576865
# 13       -94.575604
# 14       -94.649448
# 15       -94.590860
# 16       -94.464335
# 17       -94.688249
# 18       -94.691741
# 19       -94.464113
# 20       -94.576865
# 21       -94.504873
# 22       -94.586679
# 23       -94.575604
# 24       -94.576130
# 25       -94.609596
# 26       -94.597264
# 27       -94.576865
# 28       -94.575604
# 29       -94.649448
# ..              ...
# 65       -94.609596
# 66       -94.597264
# 67       -94.576865
# 68       -94.575604
# 69       -94.649448
# 70       -94.667358
# 71       -94.722614
# 72       -94.780556
# 73       -94.691741
# 74       -94.688249
# 75       -94.586679
# 76       -94.576130
# 77       -94.626594
# 78       -94.603228
# 79       -94.659304
# 80       -94.586679
# 81       -94.576130
# 82       -94.626594
# 83       -94.659304
# 84       -94.603228
# 85       -94.586679
# 86       -94.576130
# 87       -94.626594
# 88       -94.603228
# 89       -94.631839
# 90       -94.586679
# 91       -94.626594
# 92       -94.659304
# 93       -94.603228
# 94       -94.576130
#
# [95 rows x 10 columns]

# %%
mexican_restaurant_df.to_csv("../Output/mexican_restaurants.csv")

# %%
import sqlite3

# %%
conn = sqlite3.connect('../Output/places_db4.sqlite')

# %%
mexican_restaurant_df.to_sql('mexican', conn, if_exists='replace', index=False)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2130: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
pd.read_sql('select * from mexican', conn)
# Out:
#     ID               City     State   Latitude  Longitude  \
# 0    1             Belton  Missouri  38.811953 -94.531898
# 1    2             Belton  Missouri  38.811953 -94.531898
# 2    3             Belton  Missouri  38.811953 -94.531898
# 3    4             Belton  Missouri  38.811953 -94.531898
# 4    5             Belton  Missouri  38.811953 -94.531898
# 5    6            Gardner    Kansas  38.810841 -94.927187
# 6    7            Gardner    Kansas  38.810841 -94.927187
5918 NW 63rd Terrace, Kansas City           4.3       39.209164
# ..                                 ...           ...             ...
# 65        2502 NW Vivion Rd, Northmoor           4.6       39.179828
# 66     4125 N Mulberry Dr, Kansas City           4.1       39.169509
# 67  5708 N Oak Trafficway, Kansas City           4.3       39.198249
# 68  7013 N Oak Trafficway, Kansas City           4.3       39.222086
# 69   5918 NW 63rd Terrace, Kansas City           4.3       39.209164
# 70    11741 Metcalf Ave, Overland Park           4.4       38.914466
# 71             7779 Quivira Rd, Lenexa           4.4       38.987058
# 72          2034 E Santa Fe St, Olathe           4.8       38.885086
# 73     9129 Elmhurst Dr, Overland Park           4.4       38.971941
# 74       8841 W 75th St, Overland Park           4.2       38.992454
# 75     207 Southwest Blvd, Kansas City           4.3       39.089028
# 76         2512 Holmes St, Kansas City           4.1       39.081007
# 77      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 78    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 79         2610 State Ave, Kansas City           4.1       39.117097
# 80     207 Southwest Blvd, Kansas City           4.3       39.089028
# 81         2512 Holmes St, Kansas City           4.1       39.081007
# 82      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 83         2610 State Ave, Kansas City           4.1       39.117097
# 84    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 85     207 Southwest Blvd, Kansas City           4.3       39.089028
# 86         2512 Holmes St, Kansas City           4.1       39.081007
# 87      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 88    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 89         901 Kansas Ave, Kansas City           4.6       39.087198
# 90     207 Southwest Blvd, Kansas City           4.3       39.089028
# 91      903 N 7th St Trfy, Kansas City           4.4       39.114754
# 92         2610 State Ave, Kansas City           4.1       39.117097
# 93    2856 Southwest Blvd, Kansas City           4.4       39.075652
# 94         2512 Holmes St, Kansas City           4.1       39.081007
#
#     Place Longitude
# 0        -94.380168
# 1        -94.667358
# 2        -94.536494
# 3        -94.585509
# 4        -94.377841
# 5        -94.780556
# 6        -94.789541
# 7        -94.797751
# 8        -94.815382
# 9        -94.761590
# 10       -94.609596
# 11       -94.597264
# 12       -94.576865
# 13       -94.575604
# 14       -94.649448
# 15       -94.590860
# 16       -94.464335
# 17       -94.688249
# 18       -94.691741
# 19       -94.464113
# 20       -94.576865
# 21       -94.504873
# 22       -94.586679
# 23       -94.575604
# 24       -94.576130
# 25       -94.609596
# 26       -94.597264
# 27       -94.576865
# 28       -94.575604
# 29       -94.649448
# ..              ...
# 65       -94.609596
# 66       -94.597264
# 67       -94.576865
# 68       -94.575604
# 69       -94.649448
# 70       -94.667358
# 71       -94.722614
# 72       -94.780556
# 73       -94.691741
# 74       -94.688249
# 75       -94.586679
# 76       -94.576130
# 77       -94.626594
# 78       -94.603228
# 79       -94.659304
# 80       -94.586679
# 81       -94.576130
# 82       -94.626594
# 83       -94.659304
# 84       -94.603228
# 85       -94.586679
# 86       -94.576130
# 87       -94.626594
# 88       -94.603228
# 89       -94.631839
# 90       -94.586679
# 91       -94.626594
# 92       -94.659304
# 93       -94.603228
# 94       -94.576130
#
# [95 rows x 10 columns]

# %%
#connect to the database
conn = sqlite3.connect('places_db4.sqlite')
c = conn.cursor()
c.executescript('''
   BEGIN TRANSACTION;
   ALTER TABLE mexican RENAME TO mexican_OLD;
   /*create a new table with the same column names and types while
   defining a primary key for the desired column*/
   CREATE TABLE mexican (  "ID" BIGINT PRIMARY KEY NOT NULL,
                           "City" TEXT,
                           "State" TEXT,
                           "Latitude"    FLOAT,
                           "Longitude"    FLOAT,
                           "Place Name" TEXT,
                           "Place Address"    TEXT,
                           "Place Rating"    TEXT,
                           "Place Latitude"    FLOAT,
                           "Place Longitude"    FLOAT
                           );
   INSERT INTO mexican SELECT * FROM mexican_OLD;
   DROP TABLE mexican_OLD;
   COMMIT TRANSACTION;
   ''')
#close out the connection
c.close()
conn.close()
