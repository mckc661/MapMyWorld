# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
import json

# API Key
from config import gkey

# %%
# Import cities info from csv
cities_df = pd.read_csv("../Resources/KC_Metro_Cities.csv")
cities_df.head()
# Out:
#          Cities     State
# 0        Belton  Missouri
# 1       Gardner    Kansas
# 2     Gladstone  Missouri
# 3     Grandview  Missouri
# 4  Independence  Missouri

# %%
# add columns for restaurant name, restaurant address, rating
cities_df["Latitude"]=""
cities_df["Longitude"]=""
cities_df["Place Name"]=""
cities_df["Place Address"]=""
cities_df["Place Rating"]=""
cities_df["Place Latitude"]=""
cities_df["Place Longitude"]=""
cities_df.head()
# Out:
#          Cities     State Latitude Longitude Place Name Place Address  \
# 0        Belton  Missouri
# 1       Gardner    Kansas
# 2     Gladstone  Missouri
# 3     Grandview  Missouri
# 4  Independence  Missouri
#
#   Place Rating Place Latitude Place Longitude
# 0
# 1
# 2
# 3
# 4

# %%
# create params dictionary to be updated with new city each iteration
params = {"key": gkey}

# loop through cities_df and run lat/lon search for each city
for index, row in cities_df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    
    city = row["Cities"]
    state = row["State"]
    
    # update address key value
    params["address"] = f"{city},{state}"
    
    # make request
    cities_lat_lon = requests.get(base_url, params=params)
#     print(cities_lat_lon.url)
    
    # convert to json
    cities_lat_lon = cities_lat_lon.json()
    
    cities_df.loc[index, "Latitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lat"]
    cities_df.loc[index, "Longitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lng"]

#visualize to confirm
cities_df.head()
# Out:
#          Cities     State Latitude Longitude Place Name Place Address  \
# 0        Belton  Missouri   38.812  -94.5319
# 1       Gardner    Kansas  38.8108  -94.9272
# 2     Gladstone  Missouri  39.2039  -94.5547
# 3     Grandview  Missouri  38.8858   -94.533
# 4  Independence  Missouri  39.0911  -94.4155
#
#   Place Rating Place Latitude Place Longitude
# 0
# 1
# 2
# 3
# 4

# %%
# params dictionary to update each iteration
params = {
    "radius": 15000,
    "types": "restaurant",
    "keyword": "chinese",
    "key": gkey
}
k=1
# use latitude/longitude to identify chinese retaurants
for index, row in cities_df.iterrows():
# k+=1
    #     print(index)
#     get lat/lon from df
    lat = row["Latitude"]
    lon = row["Longitude"]
    
#     change location each iteration while 
#     leaving original params in place
    params["location"] = f"{lat},{lon}"
    
#     use the serach term "Chines Restaurant" and lat/lon
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
#     make request and print url
    response = requests.get(base_url, params=params)
    
#     print(response.url)

#     convert to json
    response = response.json()
#     print(json.dumps(response, indent=4, sort_keys=True))

#     since some data may be missing, use try/except to skip any missing
#     data point
#     loop through to gather 5 indices
    pkey=[]
    city_name = []
    state_name = []
    city_lat = []
    city_lon = []
    name = []
    address = []
    rating = []
    place_lat = []
    place_lon = []
    i = 0 
 
    for responses in response:
        while i < 5:
          
            try:
                pkey.append(k)
                city_name.append(row["Cities"])
                state_name.append(row["State"])
                city_lat.append(lat)
                city_lon.append(lon)
                name.append(response["results"][i]["name"])
                address.append(response["results"][i]["vicinity"])
                rating.append(response["results"][i]["rating"])
                place_lat.append(response["results"][i]["geometry"]["location"]["lat"])
                place_lon.append(response["results"][i]["geometry"]["location"]["lng"])
            except (KeyError, IndexError):
                print("Missing field/result... skipping.")
                
            i+=1
            k+=1
#     if index = 0 create a new dataframe        
    if index == 0:
        chinese_restaurant_df = pd.DataFrame({"ID":pkey,
                                            "City":city_name,
                                             "State":state_name,
                                             "Latitude":city_lat,
                                             "Longitude":city_lon,
                                             "Place Name":name,
                                             "Place Address":address,
                                             "Place Rating":rating,
                                             "Place Latitude":place_lat,
                                             "Place Longitude":place_lon})
# otherwise create a new dataframe and then append the new dataframe to [0] df
    else:
        other_chinese_df = pd.DataFrame({"ID":pkey,
                                        "City":city_name,
                                        "State":state_name,
                                        "Latitude":city_lat,
                                        "Longitude":city_lon,
                                        "Place Name":name,
                                        "Place Address":address,
                                        "Place Rating":rating,
                                        "Place Latitude":place_lat,
                                        "Place Longitude":place_lon})
        chinese_restaurant_df = chinese_restaurant_df.append(other_chinese_df).reset_index(drop=True)

# %%
chinese_restaurant_df
# Out:
#     ID               City     State   Latitude  Longitude  \
# 0    1             Belton  Missouri  38.811953 -94.531898
# 1    2             Belton  Missouri  38.811953 -94.531898
# 2    3             Belton  Missouri  38.811953 -94.531898
# 3    4             Belton  Missouri  38.811953 -94.531898
# 4    5             Belton  Missouri  38.811953 -94.531898
# 5    6            Gardner    Kansas  38.810841 -94.927187
# 6    7            Gardner    Kansas  38.810841 -94.927187
# 7    8            Gardner    Kansas  38.810841 -94.927187
# 8    9            Gardner    Kansas  38.810841 -94.927187
# 9   10            Gardner    Kansas  38.810841 -94.927187
# 10  11          Gladstone  Missouri  39.203892 -94.554677
# 11  12          Gladstone  Missouri  39.203892 -94.554677
# 12  13          Gladstone  Missouri  39.203892 -94.554677
# 13  14          Gladstone  Missouri  39.203892 -94.554677
# 14  15          Gladstone  Missouri  39.203892 -94.554677
# 15  16          Grandview  Missouri  38.885841 -94.533010
# 16  17          Grandview  Missouri  38.885841 -94.533010
# 17  18          Grandview  Missouri  38.885841 -94.533010
# 18  19          Grandview  Missouri  38.885841 -94.533010
# 19  20          Grandview  Missouri  38.885841 -94.533010
# 20  21       Independence  Missouri  39.091116 -94.415507
# 21  22       Independence  Missouri  39.091116 -94.415507
# 22  23       Independence  Missouri  39.091116 -94.415507
# 23  24       Independence  Missouri  39.091116 -94.415507
# 24  25       Independence  Missouri  39.091116 -94.415507
# 25  26        Kansas City    Kansas  39.115531 -94.626787
# 26  27        Kansas City    Kansas  39.115531 -94.626787
# 27  28        Kansas City    Kansas  39.115531 -94.626787
# 28  29        Kansas City    Kansas  39.115531 -94.626787
# 29  30        Kansas City    Kansas  39.115531 -94.626787
# ..  ..                ...       ...        ...        ...
# 65  66  North Kansas City  Missouri  39.142908 -94.572978
# 66  67  North Kansas City  Missouri  39.142908 -94.572978
# 67  68  North Kansas City  Missouri  39.142908 -94.572978
# 68  69  North Kansas City  Missouri  39.142908 -94.572978
# 69  70  North Kansas City  Missouri  39.142908 -94.572978
# 70  71             Olathe    Kansas  38.881396 -94.819128
# 71  72             Olathe    Kansas  38.881396 -94.819128
# 72  73             Olathe    Kansas  38.881396 -94.819128
# 73  74             Olathe    Kansas  38.881396 -94.819128
# 74  75             Olathe    Kansas  38.881396 -94.819128
# 75  76      Overland Park    Kansas  38.982228 -94.670792
# 76  77      Overland Park    Kansas  38.982228 -94.670792
# 77  78      Overland Park    Kansas  38.982228 -94.670792
# 78  79      Overland Park    Kansas  38.982228 -94.670792
# 79  80      Overland Park    Kansas  38.982228 -94.670792
# 80  81    Prairie Village    Kansas  38.991673 -94.633568
# 81  82    Prairie Village    Kansas  38.991673 -94.633568
# 82  83    Prairie Village    Kansas  38.991673 -94.633568
# 83  84    Prairie Village    Kansas  38.991673 -94.633568
# 84  85    Prairie Village    Kansas  38.991673 -94.633568
# 85  86            Raytown  Missouri  39.008617 -94.463564
# 86  87            Raytown  Missouri  39.008617 -94.463564
# 87  88            Raytown  Missouri  39.008617 -94.463564
# 88  89            Raytown  Missouri  39.008617 -94.463564
# 89  90            Raytown  Missouri  39.008617 -94.463564
# 90  91            Shawnee    Kansas  39.022848 -94.715187
# 91  92            Shawnee    Kansas  39.022848 -94.715187
# 92  93            Shawnee    Kansas  39.022848 -94.715187
# 93  94            Shawnee    Kansas  39.022848 -94.715187
# 94  95            Shawnee    Kansas  39.022848 -94.715187
#
#                                Place Name  \
# 0               Chinese Palace Restaurant
# 1                                 Joy Wok
# 2                            China Garden
# 3                                Bo Lings
# 4                       China One Express
# 5                            China Buffet
# 6        Golden Palace Chinese Restaurant
# 7                              Master Wok
# 8                        Jasmine Pavilion
# 9                             Chang's Wok
# 10                                Tao Tao
# 11                 Parallel China Express
# 12              New China Star Restaurant
# 13        Lucky Dragon Chinese Restaurant
# 14                              China Wok
# 15              Chinese Palace Restaurant
# 16      Jasmine Garden Chinese Restaurant
# 17          China Rose Chinese Restaurant
# 18  Jen Jens Authentic Chinese Restaurant
# 19                                Joy Wok
# 20          Lao Peking Chinese Restaurant
# 21  New Mandarin House Chinese Restaurant
# 22                             China Town
# 23         Golden Rice Chinese Restaurant
# 24           Gold Lion Chinese Restaurant
# 25           Jade Bowl Chinese Restaurant
# 26                             Dragon Inn
# 27                Sang Sang Asian Express
# 28                                KIN LIN
# 29                    China Garden Buffet
# ..                                    ...
# 65                    China Garden Buffet
# 66                               Bo Lings
# 67              Peking Chinese Restaurant
# 68                           P.F. Chang's
# 69                             New Peking
# 70              Chinese Palace Restaurant
# 71                            China Panda
# 72                               Joy Food
# 73                   China Inn Restaurant
# 74                             Master Wok
# 75                               Joy Food
# 76                           China Garden
# 77  Jen Jens Authentic Chinese Restaurant
# 78                           China Buffet
# 79                      China One Express
# 80              Chinese Palace Restaurant
# 81                            China Panda
# 82                               Joy Food
# 83                   China Inn Restaurant
# 84      Jasmine Garden Chinese Restaurant
# 85                           China Dragon
# 86                                KIN LIN
# 87                             Rice House
# 88                           Happy Dragon
# 89                               Bo Lings
# 90              Chinese Palace Restaurant
# 91                               Joy Food
# 92                   China Inn Restaurant
# 93                                Joy Wok
# 94      Jasmine Garden Chinese Restaurant
#
#                              Place Address  Place Rating  Place Latitude  \
# 0          10136 W 119th St, Overland Park           4.2       38.914108
# 1         11920 Metcalf Ave, Overland Park           3.9       38.911788
# 2           8740 W 135th St, Overland Park           4.3       38.885746
# 3           7105 W 135th St, Overland Park           4.3       38.883143
# 4          11176 Antioch Rd, Overland Park           3.2       38.925203
# 5               2030 E Santa Fe St, Olathe           3.9       38.885063
# 6                1711 S Mur-Len Rd, Olathe           4.4       38.856062
# 7                 14947 W 119th St, Olathe           4.4       38.911492
# 8              15040 S Blackbob Rd, Olathe           4.5       38.856263
# 6        -94.780592
# 7        -94.759332
# 8        -94.762022
# 9        -94.796830
# 10       -94.643386
# 11       -94.690553
# 12       -94.586923
# 13       -94.573923
# 14       -94.650561
# 15       -94.702678
# 16       -94.689105
# 17       -94.686996
# 18       -94.670061
# 19       -94.668222
# 20       -94.445921
# 21       -94.436961
# 22       -94.469544
# 23       -94.413550
# 24       -94.378278
# 25       -94.688883
# 26       -94.672522
# 27       -94.712115
# 28       -94.583474
# 29       -94.687157
# ..              ...
# 65       -94.687157
# 66       -94.594461
# 67       -94.590282
# 68       -94.588544
# 69       -94.593180
# 70       -94.702678
# 71       -94.724892
# 72       -94.725139
# 73       -94.741400
# 74       -94.759332
# 75       -94.725139
# 76       -94.687570
# 77       -94.670061
# 78       -94.780751
# 79       -94.687481
# 80       -94.702678
# 81       -94.724892
# 82       -94.725139
# 83       -94.741400
# 84       -94.689105
# 85       -94.585362
# 86       -94.583474
# 87       -94.607366
# 88       -94.606922
# 89       -94.594461
# 90       -94.702678
# 91       -94.725139
# 92       -94.741400
# 93       -94.668222
# 94       -94.689105
#
# [95 rows x 10 columns]

# %%
chinese_restaurant_df.to_csv("../Output/chinese_restaurants.csv")

# %%
import sqlite3

# %%
conn = sqlite3.connect('../Output/places_db2.sqlite')

# %%
chinese_restaurant_df.to_sql('chinese', conn, if_exists='replace', index=False)
# Out:
# C:\Users\mcoon\Anaconda3\lib\site-packages\pandas\core\generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)

# %%
pd.read_sql('select * from chinese', conn)
# Out:
#     ID               City     State   Latitude  Longitude  \
# 0    1             Belton  Missouri  38.811953 -94.531898
# 1    2             Belton  Missouri  38.811953 -94.531898
# 2    3             Belton  Missouri  38.811953 -94.531898
# 3    4             Belton  Missouri  38.811953 -94.531898
# 4    5             Belton  Missouri  38.811953 -94.531898
# 5    6            Gardner    Kansas  38.810841 -94.927187
# 6    7            Gardner    Kansas  38.810841 -94.927187
# 7    8            Gardner    Kansas  38.810841 -94.927187
# 8    9            Gardner    Kansas  38.810841 -94.927187
# 9   10            Gardner    Kansas  38.810841 -94.927187
# 10  11          Gladstone  Missouri  39.203892 -94.554677
# 11  12          Gladstone  Missouri  39.203892 -94.554677
# 12  13          Gladstone  Missouri  39.203892 -94.554677
# 13  14          Gladstone  Missouri  39.203892 -94.554677
# 14  15          Gladstone  Missouri  39.203892 -94.554677
# 15  16          Grandview  Missouri  38.885841 -94.533010
# 16  17          Grandview  Missouri  38.885841 -94.533010
# 17  18          Grandview  Missouri  38.885841 -94.533010
# 18  19          Grandview  Missouri  38.885841 -94.533010
# 19  20          Grandview  Missouri  38.885841 -94.533010
# 20  21       Independence  Missouri  39.091116 -94.415507
# 21  22       Independence  Missouri  39.091116 -94.415507
# 22  23       Independence  Missouri  39.091116 -94.415507
# 23  24       Independence  Missouri  39.091116 -94.415507
# 24  25       Independence  Missouri  39.091116 -94.415507
# 25  26        Kansas City    Kansas  39.115531 -94.626787
# 26  27        Kansas City    Kansas  39.115531 -94.626787
# 27  28        Kansas City    Kansas  39.115531 -94.626787
# 28  29        Kansas City    Kansas  39.115531 -94.626787
# 29  30        Kansas City    Kansas  39.115531 -94.626787
# ..  ..                ...       ...        ...        ...
# 65  66  North Kansas City  Missouri  39.142908 -94.572978
# 66  67  North Kansas City  Missouri  39.142908 -94.572978
# 67  68  North Kansas City  Missouri  39.142908 -94.572978
# 68  69  North Kansas City  Missouri  39.142908 -94.572978
# 69  70  North Kansas City  Missouri  39.142908 -94.572978
# 70  71             Olathe    Kansas  38.881396 -94.819128
# 71  72             Olathe    Kansas  38.881396 -94.819128
# 72  73             Olathe    Kansas  38.881396 -94.819128
# 73  74             Olathe    Kansas  38.881396 -94.819128
# 74  75             Olathe    Kansas  38.881396 -94.819128
# 75  76      Overland Park    Kansas  38.982228 -94.670792
# 76  77      Overland Park    Kansas  38.982228 -94.670792
# 77  78      Overland Park    Kansas  38.982228 -94.670792
# 78  79      Overland Park    Kansas  38.982228 -94.670792
# 79  80      Overland Park    Kansas  38.982228 -94.670792
# 80  81    Prairie Village    Kansas  38.991673 -94.633568
# 81  82    Prairie Village    Kansas  38.991673 -94.633568
# 82  83    Prairie Village    Kansas  38.991673 -94.633568
# 83  84    Prairie Village    Kansas  38.991673 -94.633568
# 84  85    Prairie Village    Kansas  38.991673 -94.633568
# 85  86            Raytown  Missouri  39.008617 -94.463564
# 86  87            Raytown  Missouri  39.008617 -94.463564
# 87  88            Raytown  Missouri  39.008617 -94.463564
# 88  89            Raytown  Missouri  39.008617 -94.463564
# 89  90            Raytown  Missouri  39.008617 -94.463564
# 90  91            Shawnee    Kansas  39.022848 -94.715187
# 91  92            Shawnee    Kansas  39.022848 -94.715187
# 92  93            Shawnee    Kansas  39.022848 -94.715187
# 93  94            Shawnee    Kansas  39.022848 -94.715187
# 94  95            Shawnee    Kansas  39.022848 -94.715187
#
#                                Place Name  \
# 0               Chinese Palace Restaurant
# 1                                 Joy Wok
# 2                            China Garden
# 3                                Bo Lings
# 4                       China One Express
# 5                            China Buffet
# 6        Golden Palace Chinese Restaurant
# 7                              Master Wok
# 8                        Jasmine Pavilion
# 9                             Chang's Wok
# 10                                Tao Tao
# 11                 Parallel China Express
# 12              New China Star Restaurant
# 13        Lucky Dragon Chinese Restaurant
# 14                              China Wok
# 15              Chinese Palace Restaurant
# 16      Jasmine Garden Chinese Restaurant
# 17          China Rose Chinese Restaurant
# 18  Jen Jens Authentic Chinese Restaurant
# 19                                Joy Wok
# 20          Lao Peking Chinese Restaurant
# 21  New Mandarin House Chinese Restaurant
# 22                             China Town
# 23         Golden Rice Chinese Restaurant
# 24           Gold Lion Chinese Restaurant
# 25           Jade Bowl Chinese Restaurant
# 26                             Dragon Inn
# 27                Sang Sang Asian Express
# 28                                KIN LIN
# 29                    China Garden Buffet
# ..                                    ...
# 65                    China Garden Buffet
# 66                               Bo Lings
# 67              Peking Chinese Restaurant
# 68                           P.F. Chang's
# 69                             New Peking
# 70              Chinese Palace Restaurant
# 71                            China Panda
# 72                               Joy Food
# 73                   China Inn Restaurant
# 74                             Master Wok
# 75                               Joy Food
# 76                           China Garden
# 77  Jen Jens Authentic Chinese Restaurant
# 78                           China Buffet
# 79                      China One Express
# 80              Chinese Palace Restaurant
# 81                            China Panda
# 82                               Joy Food
# 83                   China Inn Restaurant
# 84      Jasmine Garden Chinese Restaurant
# 85                           China Dragon
# 86                                KIN LIN
# 87                             Rice House
# 88                           Happy Dragon
# 89                               Bo Lings
# 90              Chinese Palace Restaurant
# 86              314 E 51st St, Kansas City           3.9       39.034946
# 87        13003 State Line Rd, Kansas City           4.2       38.892136
# 88      4513, 1230 W 103rd St, Kansas City           3.8       38.942847
# 89          4701 Jefferson St, Kansas City           4.1       39.042009
# 90         10136 W 119th St, Overland Park           4.2       38.914108
# 91         11920 W 119th St, Overland Park           3.5       38.913342
# 92       13412 College Blvd, Overland Park           4.2       38.929021
# 93        11920 Metcalf Ave, Overland Park           3.9       38.911788
# 94           8912 W 95th St, Overland Park           4.6       38.957289
#
#     Place Longitude
# 0        -94.702678
# 1        -94.668222
# 2        -94.687570
# 3        -94.669130
# 4        -94.687481
# 5        -94.780751
# 6        -94.780592
# 7        -94.759332
# 8        -94.762022
# 9        -94.796830
# 10       -94.643386
# 11       -94.690553
# 12       -94.586923
# 13       -94.573923
# 14       -94.650561
# 15       -94.702678
# 16       -94.689105
# 17       -94.686996
# 18       -94.670061
# 19       -94.668222
# 20       -94.445921
# 21       -94.436961
# 22       -94.469544
# 23       -94.413550
# 24       -94.378278
# 25       -94.688883
# 26       -94.672522
# 27       -94.712115
# 28       -94.583474
# 29       -94.687157
# ..              ...
# 65       -94.687157
# 66       -94.594461
# 67       -94.590282
# 68       -94.588544
# 69       -94.593180
# 70       -94.702678
# 71       -94.724892
# 72       -94.725139
# 73       -94.741400
# 74       -94.759332
# 75       -94.725139
# 76       -94.687570
# 77       -94.670061
# 78       -94.780751
# 79       -94.687481
# 80       -94.702678
# 81       -94.724892
# 82       -94.725139
# 83       -94.741400
# 84       -94.689105
# 85       -94.585362
# 86       -94.583474
# 87       -94.607366
# 88       -94.606922
# 89       -94.594461
# 90       -94.702678
# 91       -94.725139
# 92       -94.741400
# 93       -94.668222
# 94       -94.689105
#
# [95 rows x 10 columns]

# %%
#connect to the database
conn = sqlite3.connect('places_db2.sqlite')
c = conn.cursor()
c.executescript('''
    BEGIN TRANSACTION;
        ALTER TABLE chinese RENAME TO chinese_New;
    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
      CREATE TABLE chinese (
                            "ID" INT PRIMARY KEY NOT NULL,
                            "City" TEXT,
                            "State" TEXT,
                            "Latitude"    FLOAT,
                            "Longitude"    FLOAT,
                            "Place Name" TEXT,
                            "Place Address"    TEXT,
                            "Place Rating"    TEXT,
                            "Place Latitude"    FLOAT,
                            "Place Longitude"    FLOAT
                            );
                            
    INSERT INTO chinese SELECT * FROM chinese_New;
    DROP TABLE chinese_New;                       

    COMMIT TRANSACTION;
    ''')
#close out the connection
c.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-50-b86eead7f003> in <module>
#       7
#       8     COMMIT TRANSACTION;
# ----> 9     ''')
#      10 #close out the connection
#      11 c.close()
#
# OperationalError: near "PRIMARY": syntax error

# %%
    ALTER TABLE chinese RENAME TO chinese_New;
    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    CREATE TABLE chinese (
                            "ID" INT PRIMARY KEY NOT NULL,
                            "City" TEXT,
                            "State" TEXT,
                            "Latitude"    FLOAT,
                            "Longitude"    FLOAT,
                            "Place Name" TEXT,
                            "Place Address"    TEXT,
                            "Place Rating"    TEXT,
                            "Place Latitude"    FLOAT,
                            "Place Longitude"    FLOAT
                            );
    
    INSERT INTO chinese SELECT * FROM chinese_New;
    DROP TABLE chinese_New;
