# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
import json

# API Key
from config import gkey

# %%
# Import cities info from csv
cities_df = pd.read_csv("../Resources/KC_Metro_Cities.csv")
cities_df.head()
# Out:
#               Cities     State
# 0           Avondale  Missouri
# 1            Basehor    Kansas
# 2             Belton  Missouri
# 3       Blue Springs  Missouri
# 4  Excelsior Springs  Missouri

# %%
# add columns for restaurant name, restaurant address, rating
cities_df["Latitude"]=""
cities_df["Longitude"]=""
cities_df["Restaurant Name"]=""
cities_df["Restaurant Address"]=""
cities_df["Restaurant Rating"]=""
cities_df = cities_df[["Cities", "State", "Latitude", "Longitude", 
                       "Restaurant Name", "Restaurant Address", 
                       "Restaurant Rating"]]
cities_df.head()
# Out:
#               Cities     State Latitude Longitude Restaurant Name  \
# 0           Avondale  Missouri
# 1            Basehor    Kansas
# 2             Belton  Missouri
# 3       Blue Springs  Missouri
# 4  Excelsior Springs  Missouri
#
#   Restaurant Address Restaurant Rating
# 0
# 1
# 2
# 3
# 4

# %%
# create params dictionary to be updated with new city each iteration
params = {"key": gkey}

# loop through cities_df and run lat/lon search for each city
for index, row in cities_df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    
    city = row['Cities']
    state = row['State']
    
    # update address key value
    params['address'] = f"{city},{state}"
    
    # make request
    cities_lat_lon = requests.get(base_url, params=params)
    
    # convert to json
    cities_lat_lon = cities_lat_lon.json()
    
    cities_df.loc[index, "Latitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lat"]
    cities_df.loc[index, "Longitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lng"]

#visualize to confirm
cities_df.head()
# Out:
#               Cities     State Latitude Longitude Restaurant Name  \
# 0           Avondale  Missouri  39.1542  -94.5469
# 1            Basehor    Kansas  39.1417  -94.9386
# 2             Belton  Missouri   38.812  -94.5319
# 3       Blue Springs  Missouri   39.017  -94.2816
# 4  Excelsior Springs  Missouri  39.3392  -94.2261
#
#   Restaurant Address Restaurant Rating
# 0
# 1
# 2
# 3
# 4

# %%
# params dictinoary to updte each iteration
params = {
    "radius": 15000,
    "types": "restaurant",
    "keyword": "chinese",
    "key": gkey
}

# use latitude/longitude to identify chinese retaurants
for index, row in cities_df.iterrows():
#     get lat/lon from df
    lat = row["Latitude"]
    lon = row["Longitude"]
    
#     change location each iteration while 
#     leaving original params in place
    params["location"] = f"{lat},{lon}"
    
#     use the serach term "Chines Restaurant" and lat/lon
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
#     make request and print url
    restaurant_address = requests.get(base_url, params=params)
    
#     print(restaurant_address.url)

#     convert to json
    restaurant_address = restaurant_address.json()
#     print(json.dumps(restaurant_address, indent=4, sort_keys=True))

#     since some data may be missing, use try/except to skip any missing
#     data point
    try:
        cities_df.iloc[index, "Restaurant Name"] = restaurant_address["results"][0, 10]["name"]
        cities_df.iloc[index, "Restaurant Address"] = restaurant_address["results"][0, 10]["vicinity"]
        cities_df.iloc[index, "Restaurant Rating"] = restaurant_address["results"][0, 10]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ee6a4c754d90> in <module>
#      32 #     data point
#      33     try:
# ---> 34         cities_df.iloc[index, "Restaurant Name"] = restaurant_address["results"][0, 10]["name"]
#      35         cities_df.iloc[index, "Restaurant Address"] = restaurant_address["results"][0, 10]["vicinity"]
#      36         cities_df.iloc[index, "Restaurant Rating"] = restaurant_address["results"][0, 10]["rating"]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
cities_df.head()
# Out:
#               Cities     State  Latitude  Longitude  \
# 0           Avondale  Missouri   39.1542   -94.5469
# 1            Basehor    Kansas   39.1417   -94.9386
# 2             Belton  Missouri   38.8120   -94.5319
# 3       Blue Springs  Missouri   39.0170   -94.2816
# 4  Excelsior Springs  Missouri   39.3392   -94.2261
#
#                  Restaurant Name                        Restaurant Address  \
# 0                        KIN LIN                314 E 51st St, Kansas City
# 1                 Chinese Buffet               7914 State Ave, Kansas City
# 2      Chinese Palace Restaurant           10136 W 119th St, Overland Park
# 3  Lao Peking Chinese Restaurant       1020 S Sterling Ave A, Independence
# 4               Hunan Restaurant  1101 N Jesse James Rd, Excelsior Springs
#
#   Restaurant Rating
# 0               3.9
# 1               3.9
# 2               4.2
# 3               3.9
# 4               4.3
