# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
import json

# API Key
from config import gkey

# %%
# Import cities info from csv
cities_df = pd.read_csv("../Resources/KC_Metro_Cities.csv")
cities_df.head()
# Out:
#          Cities     State
# 0        Belton  Missouri
# 1       Gardner    Kansas
# 2     Gladstone  Missouri
# 3     Grandview  Missouri
# 4  Independence  Missouri

# %%
# add columns for restaurant name, restaurant address, rating
cities_df["Latitude"]=""
cities_df["Longitude"]=""
cities_df["PlaceName"]=""
cities_df["PlaceAddress"]=""
cities_df["PlaceRating"]=""
cities_df["PlaceLatitude"]=""
cities_df["PlaceLongitude"]=""
cities_df.head()
# Out:
#          Cities     State Latitude Longitude PlaceName PlaceAddress  \
# 0        Belton  Missouri
# 1       Gardner    Kansas
# 2     Gladstone  Missouri
# 3     Grandview  Missouri
# 4  Independence  Missouri
#
#   PlaceRating PlaceLatitude PlaceLongitude
# 0
# 1
# 2
# 3
# 4

# %%
# create params dictionary to be updated with new city each iteration
params = {"key": gkey}

# loop through cities_df and run lat/lon search for each city
for index, row in cities_df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    
    city = row["Cities"]
    state = row["State"]
    
    # update address key value
    params["address"] = f"{city},{state}"
    
    # make request
    cities_lat_lon = requests.get(base_url, params=params)
#     print(cities_lat_lon.url)
    
    # convert to json
    cities_lat_lon = cities_lat_lon.json()
    
    cities_df.loc[index, "Latitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lat"]
    cities_df.loc[index, "Longitude"]=cities_lat_lon["results"][0]["geometry"]["location"]["lng"]

#visualize to confirm
cities_df.head()
# Out:
#          Cities     State Latitude Longitude PlaceName PlaceAddress  \
# 0        Belton  Missouri   38.812  -94.5319
# 1       Gardner    Kansas  38.8108  -94.9272
# 2     Gladstone  Missouri  39.2039  -94.5547
# 3     Grandview  Missouri  38.8858   -94.533
# 4  Independence  Missouri  39.0911  -94.4155
#
#   PlaceRating PlaceLatitude PlaceLongitude
# 0
# 1
# 2
# 3
# 4

# %%
# params dictionary to update each iteration
params = {
    "radius": 15000,
    "types": "gas_station",
    "key": gkey
}
k=1
# use latitude/longitude to identify chinese retaurants
for index, row in cities_df.iterrows():
#     print(index)
#     get lat/lon from df
    lat = row["Latitude"]
    lon = row["Longitude"]
    
#     change location each iteration while 
#     leaving original params in place
    params["location"] = f"{lat},{lon}"
    
#     use the serach term "Chines Restaurant" and lat/lon
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
#     make request and print url
    response = requests.get(base_url, params=params)
    
#     print(response.url)

#     convert to json
    response = response.json()
#     print(json.dumps(response, indent=4, sort_keys=True))

#     since some data may be missing, use try/except to skip any missing
#     data point
#     loop through to gather 5 indices
    pkey = []
    city_name = []
    state_name = []
    city_lat = []
    city_lon = []
    name = []
    address = []
    rating = []
    place_lat = []
    place_lon = []
    i = 0
    for responses in response:
        while i < 5:
            try:
                pkey.append(k)
                city_name.append(row["Cities"])
                state_name.append(row["State"])
                city_lat.append(lat)
                city_lon.append(lon)
                name.append(response["results"][i]["name"])
                address.append(response["results"][i]["vicinity"])
                rating.append(response["results"][i]["rating"])
                place_lat.append(response["results"][i]["geometry"]["location"]["lat"])
                place_lon.append(response["results"][i]["geometry"]["location"]["lng"])
            except (KeyError, IndexError):
                print("Missing field/result... skipping.")
        
            i+=1
            k+=1
#     if index = 0 create a new dataframe        
    if index == 0:
        gas_df = pd.DataFrame({"ID":pkey, "City":city_name,
                                             "State":state_name,
                                             "Latitude":city_lat,
                                             "Longitude":city_lon,
                                             "PlaceName":name,
                                             "PlaceAddress":address,
                                             "PlaceRating":rating,
                                             "PlaceLatitude":place_lat,
                                             "PlaceLongitude":place_lon})
# otherwise create a new dataframe and then append the new dataframe to [0] df
    else:
        other_gas_df = pd.DataFrame({"ID":pkey,"City":city_name,
                                        "State":state_name,
                                        "Latitude":city_lat,
                                        "Longitude":city_lon,
                                        "PlaceName":name,
                                        "PlaceAddress":address,
                                        "PlaceRating":rating,
                                        "PlaceLatitude":place_lat,
                                        "PlaceLongitude":place_lon})
        gas_df = gas_df.append(other_gas_df).reset_index(drop=True)

# %%
gas_df
# Out:
#     ID               City     State   Latitude  Longitude  \
# 0    1             Belton  Missouri  38.811953 -94.531898
# 1    2             Belton  Missouri  38.811953 -94.531898
# 2    3             Belton  Missouri  38.811953 -94.531898
# 3    4             Belton  Missouri  38.811953 -94.531898
# 4    5             Belton  Missouri  38.811953 -94.531898
# 5    6            Gardner    Kansas  38.810841 -94.927187
# 6    7            Gardner    Kansas  38.810841 -94.927187
# 7    8            Gardner    Kansas  38.810841 -94.927187
# 8    9            Gardner    Kansas  38.810841 -94.927187
# 9   10            Gardner    Kansas  38.810841 -94.927187
# 10  11          Gladstone  Missouri  39.203892 -94.554677
# 11  12          Gladstone  Missouri  39.203892 -94.554677
# 12  13          Gladstone  Missouri  39.203892 -94.554677
# 13  14          Gladstone  Missouri  39.203892 -94.554677
# 14  15          Gladstone  Missouri  39.203892 -94.554677
# 15  16          Grandview  Missouri  38.885841 -94.533010
# 16  17          Grandview  Missouri  38.885841 -94.533010
# 17  18          Grandview  Missouri  38.885841 -94.533010
# 18  19          Grandview  Missouri  38.885841 -94.533010
# 19  20          Grandview  Missouri  38.885841 -94.533010
# 20  21       Independence  Missouri  39.091116 -94.415507
# 21  22       Independence  Missouri  39.091116 -94.415507
# 22  23       Independence  Missouri  39.091116 -94.415507
# 23  24       Independence  Missouri  39.091116 -94.415507
# 24  25       Independence  Missouri  39.091116 -94.415507
# 25  26        Kansas City    Kansas  39.115531 -94.626787
# 26  27        Kansas City    Kansas  39.115531 -94.626787
# 27  28        Kansas City    Kansas  39.115531 -94.626787
# 28  29        Kansas City    Kansas  39.115531 -94.626787
# 29  30        Kansas City    Kansas  39.115531 -94.626787
# ..  ..                ...       ...        ...        ...
# 65  66  North Kansas City  Missouri  39.142908 -94.572978
# 66  67  North Kansas City  Missouri  39.142908 -94.572978
# 67  68  North Kansas City  Missouri  39.142908 -94.572978
# 68  69  North Kansas City  Missouri  39.142908 -94.572978
# 69  70  North Kansas City  Missouri  39.142908 -94.572978
# 70  71             Olathe    Kansas  38.881396 -94.819128
# 71  72             Olathe    Kansas  38.881396 -94.819128
# 72  73             Olathe    Kansas  38.881396 -94.819128
# 73  74             Olathe    Kansas  38.881396 -94.819128
# 74  75             Olathe    Kansas  38.881396 -94.819128
# 75  76      Overland Park    Kansas  38.982228 -94.670792
# 76  77      Overland Park    Kansas  38.982228 -94.670792
# 77  78      Overland Park    Kansas  38.982228 -94.670792
# 78  79      Overland Park    Kansas  38.982228 -94.670792
# 79  80      Overland Park    Kansas  38.982228 -94.670792
# 80  81    Prairie Village    Kansas  38.991673 -94.633568
# 81  82    Prairie Village    Kansas  38.991673 -94.633568
# 82  83    Prairie Village    Kansas  38.991673 -94.633568
# 83  84    Prairie Village    Kansas  38.991673 -94.633568
# 84  85    Prairie Village    Kansas  38.991673 -94.633568
# 85  86            Raytown  Missouri  39.008617 -94.463564
# 86  87            Raytown  Missouri  39.008617 -94.463564
# 87  88            Raytown  Missouri  39.008617 -94.463564
# 88  89            Raytown  Missouri  39.008617 -94.463564
# 89  90            Raytown  Missouri  39.008617 -94.463564
# 90  91            Shawnee    Kansas  39.022848 -94.715187
# 91  92            Shawnee    Kansas  39.022848 -94.715187
# 92  93            Shawnee    Kansas  39.022848 -94.715187
# 93  94            Shawnee    Kansas  39.022848 -94.715187
# 94  95            Shawnee    Kansas  39.022848 -94.715187
#
#                                     PlaceName  \
# 0                      Flying J Travel Center
# 1                                 Phillips 66
# 2                            Harmon Food Shop
# 3                     Zipz Convenience Stores
# 4                                 Phillips 66
# 5                                    QuikTrip
# 6                                     Casey's
# 7                                    7-Eleven
# 8                             E & J Food Mart
# 9                                    QuikTrip
# 10                                   QuikTrip
# 11                     Flying J Travel Center
# 12                                   QuikTrip
# 13                                      Shell
# 14                                         BP
# 15                                   QuikTrip
# 16                              Royal Liquors
# 17                                   QuikTrip
# 18                                Phillips 66
# 19                  Gomer's Gas & Convenience
# 20                                         BP
# 21                                      Spire
# 22                                   QuikTrip
# 23                                   QuikTrip
# 24                     Flying J Travel Center
# 25                                         BP
# 26                                         BP
# 27                                   QuikTrip
# 28                                   QuikTrip
# 29                                   QuikTrip
# ..                                        ...
# 65                                         BP
# 66                                   QuikTrip
# 67                                   QuikTrip
# 68                                   QuikTrip
# 69                     Flying J Travel Center
# 70  Phillips 66- Fuel Mart & Discount Tobacco
# 71                                         BP
# 72                                 Hy-Vee Gas
# 73                                   QuikTrip
# 74                                   QuikTrip
# 75                                         BP
# 76                                         BP
# 77                                   QuikTrip
# 78  Phillips 66- Fuel Mart & Discount Tobacco
# 79                                         BP
# 80                                         BP
# 81                                         BP
# 82                                         BP
# 83                                   QuikTrip
# 84                                   QuikTrip
# 85                                         BP
# 86                                      Spire
# 87                                   QuikTrip
# 88                      Brookside 66 Services
# 89                                   QuikTrip
# 90                                         BP
# 91                                         BP
# 92                                   QuikTrip
# 93  Phillips 66- Fuel Mart & Discount Tobacco
# 94                                   QuikTrip
#
#                                       PlaceAddress  PlaceRating  \
# 0                              700 J Hwy, Peculiar          3.9
# 1               125 West 135th Street, Kansas City          4.3
# 2                101 South Madison Street, Raymore          1.0
# 3                     6100 Missouri 150, Grandview          3.3
# 4                    500 East North Avenue, Belton          3.9
# 5                1234 East Santa Fe Street, Olathe          4.2
# 6                      18315 Gardner Road, Gardner          3.0
# 7                  951 South Parker Street, Olathe          3.3
# 8                    432 East Main Street, Gardner          4.3
# 9                    694 East Main Street, Gardner          4.2
# 10         7100 Northeast Parvin Road, Kansas City          4.6
# 11       1300 North Corrington Avenue, Kansas City          3.4
# 12         5108 Northeast Vivion Road, Kansas City          4.2
# 13         5401 Northwest 64th Street, Kansas City          3.0
# 14                       17 E U.S. 69, Kansas City          4.5
# 15                 10232 Wornall Road, Kansas City          4.5
# 16             1301 West 103rd Street, Kansas City          4.1
# 17               11902 Riley Street, Overland Park          4.1
# 18              125 West 135th Street, Kansas City          4.3
# 19                   9908 Holmes Road, Kansas City          3.0
# 20             3319 Linwood Boulevard, Kansas City          3.3
# 21        1117 South Pleasant Street, Independence          2.6
# 22         7100 Northeast Parvin Road, Kansas City          4.6
# 23  1301 Northwest Woods Chapel Road, Blue Springs          4.4
# 24       1300 North Corrington Avenue, Kansas City          3.4
# 25             3319 Linwood Boulevard, Kansas City          3.3
# 26                     5500 Johnson Drive, Mission          4.0
# 27                   4327 Main Street, Kansas City          3.7
# 28           3101 Southwest Boulevard, Kansas City          4.0
# 29                      4700 Lamar Avenue, Mission          3.9
# ..                                             ...          ...
# 65             3319 Linwood Boulevard, Kansas City          3.3
# 66                   4327 Main Street, Kansas City          3.7
# 67           3101 Southwest Boulevard, Kansas City          4.0
# 68         7100 Northeast Parvin Road, Kansas City          4.6
# 69       1300 North Corrington Avenue, Kansas City          3.4
# 70            12085 South Strang Line Road, Olathe          4.0
# 71                  10700 West 87th Street, Lenexa          3.7
# 72                 17901 West 119th Street, Olathe          3.4
# 73                       11070 Pflumm Road, Lenexa          4.2
# 74               1234 East Santa Fe Street, Olathe          4.2
# 75                  10700 West 87th Street, Lenexa          3.7
# 76                     5500 Johnson Drive, Mission          4.0
# 77                   4327 Main Street, Kansas City          3.7
# 78            12085 South Strang Line Road, Olathe          4.0
# 79             3319 Linwood Boulevard, Kansas City          3.3
# 80             3319 Linwood Boulevard, Kansas City          3.3
# 81                  10700 West 87th Street, Lenexa          3.7
# 82                     5500 Johnson Drive, Mission          4.0
# 83                   4327 Main Street, Kansas City          3.7
# 84                 10232 Wornall Road, Kansas City          4.5
# 85             3319 Linwood Boulevard, Kansas City          3.3
# 86        1117 South Pleasant Street, Independence          2.6
# 87                   4327 Main Street, Kansas City          3.7
# 88                   6244 Main Street, Kansas City          3.5
# 89                 10232 Wornall Road, Kansas City          4.5
# 90                  10700 West 87th Street, Lenexa          3.7
# 91                     5500 Johnson Drive, Mission          4.0
# 92                   4327 Main Street, Kansas City          3.7
# 93            12085 South Strang Line Road, Olathe          4.0
# 94                      4700 Lamar Avenue, Mission          3.9
#
#     PlaceLatitude  PlaceLongitude
# 0       38.722789      -94.451101
# 1       38.882638      -94.597747
# 2       38.804337      -94.456655
# 3       38.858688      -94.523916
# 4       38.814667      -94.525187
# 5       38.884402      -94.797624
# 6       38.796039      -94.927044
# 7       38.869520      -94.835079
# 8       38.811316      -94.919096
# 9       38.811487      -94.912989
# 10      39.169546      -94.496395
# 11      39.130681      -94.496822
# 12      39.188336      -94.519931
# 13      39.209971      -94.643429
# 14      39.195299      -94.506671
# 15      38.943071      -94.597092
# 16      38.941677      -94.607385
# 17      38.912546      -94.673029
# 18      38.882638      -94.597747
# 19      38.948048      -94.582837
# 20      39.067453      -94.544134
# 21      39.079817      -94.421444
# 22      39.169546      -94.496395
# 23      39.031414      -94.305693
# 24      39.130681      -94.496822
# 25      39.067453      -94.544134
# 26      39.022451      -94.649456
# 27      39.048271      -94.586196
# 28      39.071811      -94.607256
# 29      39.042964      -94.656498
# ..            ...             ...
# 65      39.067453      -94.544134
# 66      39.048271      -94.586196
# 67      39.071811      -94.607256
# 68      39.169546      -94.496395
# 69      39.130681      -94.496822
# 70      38.909729      -94.771106
# 71      38.971326      -94.710076
# 72      38.912304      -94.792954
# 73      38.928270      -94.742909
# 74      38.884402      -94.797624
# 75      38.971326      -94.710076
# 76      39.022451      -94.649456
# 77      39.048271      -94.586196
# 78      38.909729      -94.771106
# 79      39.067453      -94.544134
# 80      39.067453      -94.544134
# 81      38.971326      -94.710076
# 82      39.022451      -94.649456
# 83      39.048271      -94.586196
# 84      38.943071      -94.597092
# 85      39.067453      -94.544134
# 86      39.079817      -94.421444
# 87      39.048271      -94.586196
# 88      39.014195      -94.588611
# 89      38.943071      -94.597092
# 90      38.971326      -94.710076
# 91      39.022451      -94.649456
# 92      39.048271      -94.586196
# 93      38.909729      -94.771106
# 94      39.042964      -94.656498
#
# [95 rows x 10 columns]

# %%
gas_df.to_csv("../Output/gas_stations.csv")

# %%
import sqlite3

# %%
conn = sqlite3.connect('../Output/places_db5.sqlite')

# %%
gas_df.to_sql('gas_stations', conn, if_exists='replace', index=False)

# %%
pd.read_sql('select * from gas_stations', conn)
# Out:
#     ID               City     State   Latitude  Longitude  \
# 0    1             Belton  Missouri  38.811953 -94.531898
# 1    2             Belton  Missouri  38.811953 -94.531898
# 2    3             Belton  Missouri  38.811953 -94.531898
# 3    4             Belton  Missouri  38.811953 -94.531898
# 4    5             Belton  Missouri  38.811953 -94.531898
# 5    6            Gardner    Kansas  38.810841 -94.927187
# 6    7            Gardner    Kansas  38.810841 -94.927187
# 7    8            Gardner    Kansas  38.810841 -94.927187
# 8    9            Gardner    Kansas  38.810841 -94.927187
# 9   10            Gardner    Kansas  38.810841 -94.927187
# 10  11          Gladstone  Missouri  39.203892 -94.554677
# 11  12          Gladstone  Missouri  39.203892 -94.554677
# 12  13          Gladstone  Missouri  39.203892 -94.554677
# 13  14          Gladstone  Missouri  39.203892 -94.554677
# 14  15          Gladstone  Missouri  39.203892 -94.554677
# 15  16          Grandview  Missouri  38.885841 -94.533010
# 16  17          Grandview  Missouri  38.885841 -94.533010
# 17  18          Grandview  Missouri  38.885841 -94.533010
# 18  19          Grandview  Missouri  38.885841 -94.533010
# 19  20          Grandview  Missouri  38.885841 -94.533010
# 20  21       Independence  Missouri  39.091116 -94.415507
# 21  22       Independence  Missouri  39.091116 -94.415507
# 22  23       Independence  Missouri  39.091116 -94.415507
# 23  24       Independence  Missouri  39.091116 -94.415507
# 24  25       Independence  Missouri  39.091116 -94.415507
# 25  26        Kansas City    Kansas  39.115531 -94.626787
# 26  27        Kansas City    Kansas  39.115531 -94.626787
# 27  28        Kansas City    Kansas  39.115531 -94.626787
# 28  29        Kansas City    Kansas  39.115531 -94.626787
# 29  30        Kansas City    Kansas  39.115531 -94.626787
# ..  ..                ...       ...        ...        ...
# 65  66  North Kansas City  Missouri  39.142908 -94.572978
# 66  67  North Kansas City  Missouri  39.142908 -94.572978
# 67  68  North Kansas City  Missouri  39.142908 -94.572978
# 68  69  North Kansas City  Missouri  39.142908 -94.572978
# 69  70  North Kansas City  Missouri  39.142908 -94.572978
# 70  71             Olathe    Kansas  38.881396 -94.819128
# 71  72             Olathe    Kansas  38.881396 -94.819128
# 72  73             Olathe    Kansas  38.881396 -94.819128
# 73  74             Olathe    Kansas  38.881396 -94.819128
# 74  75             Olathe    Kansas  38.881396 -94.819128
# 75  76      Overland Park    Kansas  38.982228 -94.670792
# 76  77      Overland Park    Kansas  38.982228 -94.670792
# 77  78      Overland Park    Kansas  38.982228 -94.670792
# 78  79      Overland Park    Kansas  38.982228 -94.670792
# 79  80      Overland Park    Kansas  38.982228 -94.670792
# 80  81    Prairie Village    Kansas  38.991673 -94.633568
# 81  82    Prairie Village    Kansas  38.991673 -94.633568
# 82  83    Prairie Village    Kansas  38.991673 -94.633568
# 83  84    Prairie Village    Kansas  38.991673 -94.633568
# 84  85    Prairie Village    Kansas  38.991673 -94.633568
# 85  86            Raytown  Missouri  39.008617 -94.463564
# 86  87            Raytown  Missouri  39.008617 -94.463564
# 87  88            Raytown  Missouri  39.008617 -94.463564
# 88  89            Raytown  Missouri  39.008617 -94.463564
# 89  90            Raytown  Missouri  39.008617 -94.463564
# 90  91            Shawnee    Kansas  39.022848 -94.715187
# 91  92            Shawnee    Kansas  39.022848 -94.715187
# 92  93            Shawnee    Kansas  39.022848 -94.715187
# 93  94            Shawnee    Kansas  39.022848 -94.715187
# 94  95            Shawnee    Kansas  39.022848 -94.715187
#
#                                     PlaceName  \
# 0                      Flying J Travel Center
# 1                                 Phillips 66
# 2                            Harmon Food Shop
# 3                     Zipz Convenience Stores
# 4                                 Phillips 66
# 5                                    QuikTrip
# 6                                     Casey's
# 7                                    7-Eleven
# 8                             E & J Food Mart
# 9                                    QuikTrip
# 10                                   QuikTrip
# 11                     Flying J Travel Center
# 12                                   QuikTrip
# 13                                      Shell
# 14                                         BP
# 15                                   QuikTrip
# 16                              Royal Liquors
# 17                                   QuikTrip
# 18                                Phillips 66
# 19                  Gomer's Gas & Convenience
# 20                                         BP
# 21                                      Spire
# 22                                   QuikTrip
# 23                                   QuikTrip
# 24                     Flying J Travel Center
# 25                                         BP
# 26                                         BP
# 27                                   QuikTrip
# 28                                   QuikTrip
# 29                                   QuikTrip
# ..                                        ...
# 65                                         BP
# 66                                   QuikTrip
# 67                                   QuikTrip
# 68                                   QuikTrip
# 69                     Flying J Travel Center
# 70  Phillips 66- Fuel Mart & Discount Tobacco
# 71                                         BP
# 72                                 Hy-Vee Gas
# 73                                   QuikTrip
# 74                                   QuikTrip
# 75                                         BP
# 76                                         BP
# 77                                   QuikTrip
# 78  Phillips 66- Fuel Mart & Discount Tobacco
# 79                                         BP
# 80                                         BP
# 81                                         BP
# 82                                         BP
# 83                                   QuikTrip
# 84                                   QuikTrip
# 85                                         BP
# 86                                      Spire
# 87                                   QuikTrip
# 88                      Brookside 66 Services
# 89                                   QuikTrip
# 90                                         BP
# 91                                         BP
# 92                                   QuikTrip
# 93  Phillips 66- Fuel Mart & Discount Tobacco
# 94                                   QuikTrip
#
#                                       PlaceAddress  PlaceRating  \
# 0                              700 J Hwy, Peculiar          3.9
# 1               125 West 135th Street, Kansas City          4.3
# 2                101 South Madison Street, Raymore          1.0
# 3                     6100 Missouri 150, Grandview          3.3
# 4                    500 East North Avenue, Belton          3.9
# 5                1234 East Santa Fe Street, Olathe          4.2
# 6                      18315 Gardner Road, Gardner          3.0
# 7                  951 South Parker Street, Olathe          3.3
# 8                    432 East Main Street, Gardner          4.3
# 9                    694 East Main Street, Gardner          4.2
# 10         7100 Northeast Parvin Road, Kansas City          4.6
# 11       1300 North Corrington Avenue, Kansas City          3.4
# 12         5108 Northeast Vivion Road, Kansas City          4.2
# 13         5401 Northwest 64th Street, Kansas City          3.0
# 14                       17 E U.S. 69, Kansas City          4.5
# 15                 10232 Wornall Road, Kansas City          4.5
# 16             1301 West 103rd Street, Kansas City          4.1
# 17               11902 Riley Street, Overland Park          4.1
# 18              125 West 135th Street, Kansas City          4.3
# 19                   9908 Holmes Road, Kansas City          3.0
# 20             3319 Linwood Boulevard, Kansas City          3.3
# 21        1117 South Pleasant Street, Independence          2.6
# 22         7100 Northeast Parvin Road, Kansas City          4.6
# 23  1301 Northwest Woods Chapel Road, Blue Springs          4.4
# 24       1300 North Corrington Avenue, Kansas City          3.4
# 25             3319 Linwood Boulevard, Kansas City          3.3
# 26                     5500 Johnson Drive, Mission          4.0
# 27                   4327 Main Street, Kansas City          3.7
# 28           3101 Southwest Boulevard, Kansas City          4.0
# 29                      4700 Lamar Avenue, Mission          3.9
# ..                                             ...          ...
# 65             3319 Linwood Boulevard, Kansas City          3.3
# 66                   4327 Main Street, Kansas City          3.7
# 67           3101 Southwest Boulevard, Kansas City          4.0
# 68         7100 Northeast Parvin Road, Kansas City          4.6
# 69       1300 North Corrington Avenue, Kansas City          3.4
# 70            12085 South Strang Line Road, Olathe          4.0
# 71                  10700 West 87th Street, Lenexa          3.7
# 72                 17901 West 119th Street, Olathe          3.4
# 73                       11070 Pflumm Road, Lenexa          4.2
# 74               1234 East Santa Fe Street, Olathe          4.2
# 75                  10700 West 87th Street, Lenexa          3.7
# 76                     5500 Johnson Drive, Mission          4.0
# 77                   4327 Main Street, Kansas City          3.7
# 78            12085 South Strang Line Road, Olathe          4.0
# 79             3319 Linwood Boulevard, Kansas City          3.3
# 80             3319 Linwood Boulevard, Kansas City          3.3
# 81                  10700 West 87th Street, Lenexa          3.7
# 82                     5500 Johnson Drive, Mission          4.0
# 83                   4327 Main Street, Kansas City          3.7
# 84                 10232 Wornall Road, Kansas City          4.5
# 85             3319 Linwood Boulevard, Kansas City          3.3
# 86        1117 South Pleasant Street, Independence          2.6
# 87                   4327 Main Street, Kansas City          3.7
# 88                   6244 Main Street, Kansas City          3.5
# 89                 10232 Wornall Road, Kansas City          4.5
# 90                  10700 West 87th Street, Lenexa          3.7
# 91                     5500 Johnson Drive, Mission          4.0
# 92                   4327 Main Street, Kansas City          3.7
# 93            12085 South Strang Line Road, Olathe          4.0
# 94                      4700 Lamar Avenue, Mission          3.9
#
#     PlaceLatitude  PlaceLongitude
# 0       38.722789      -94.451101
# 1       38.882638      -94.597747
# 2       38.804337      -94.456655
# 3       38.858688      -94.523916
# 4       38.814667      -94.525187
# 5       38.884402      -94.797624
# 6       38.796039      -94.927044
# 7       38.869520      -94.835079
# 8       38.811316      -94.919096
# 9       38.811487      -94.912989
# 10      39.169546      -94.496395
# 11      39.130681      -94.496822
# 12      39.188336      -94.519931
# 13      39.209971      -94.643429
# 14      39.195299      -94.506671
# 15      38.943071      -94.597092
# 16      38.941677      -94.607385
# 17      38.912546      -94.673029
# 18      38.882638      -94.597747
# 19      38.948048      -94.582837
# 20      39.067453      -94.544134
# 21      39.079817      -94.421444
# 22      39.169546      -94.496395
# 23      39.031414      -94.305693
# 24      39.130681      -94.496822
# 25      39.067453      -94.544134
# 26      39.022451      -94.649456
# 27      39.048271      -94.586196
# 28      39.071811      -94.607256
# 29      39.042964      -94.656498
# ..            ...             ...
# 65      39.067453      -94.544134
# 66      39.048271      -94.586196
# 67      39.071811      -94.607256
# 68      39.169546      -94.496395
# 69      39.130681      -94.496822
# 70      38.909729      -94.771106
# 71      38.971326      -94.710076
# 72      38.912304      -94.792954
# 73      38.928270      -94.742909
# 74      38.884402      -94.797624
# 75      38.971326      -94.710076
# 76      39.022451      -94.649456
# 77      39.048271      -94.586196
# 78      38.909729      -94.771106
# 79      39.067453      -94.544134
# 80      39.067453      -94.544134
# 81      38.971326      -94.710076
# 82      39.022451      -94.649456
# 83      39.048271      -94.586196
# 84      38.943071      -94.597092
# 85      39.067453      -94.544134
# 86      39.079817      -94.421444
# 87      39.048271      -94.586196
# 88      39.014195      -94.588611
# 89      38.943071      -94.597092
# 90      38.971326      -94.710076
# 91      39.022451      -94.649456
# 92      39.048271      -94.586196
# 93      38.909729      -94.771106
# 94      39.042964      -94.656498
#
# [95 rows x 10 columns]

# %%
#connect to the database
conn = sqlite3.connect('places_db5.sqlite')
c = conn.cursor()
c.executescript('''
   BEGIN TRANSACTION;
   ALTER TABLE gas_stations RENAME TO gas_stations_OLD;
   /*create a new table with the same column names and types while
   defining a primary key for the desired column*/
   CREATE TABLE gas_stations (  "ID" BIGINT PRIMARY KEY NOT NULL,
                           "City" TEXT,
                           "State" TEXT,
                           "Latitude"    FLOAT,
                           "Longitude"    FLOAT,
                           "PlaceName" TEXT,
                           "PlaceAddress"    TEXT,
                           "PlaceRating"    TEXT,
                           "PlaceLatitude"    FLOAT,
                           "PlaceLongitude"    FLOAT
                           );
   INSERT INTO gas_stations SELECT * FROM gas_stations_OLD;
   DROP TABLE gas_stations_OLD;
   COMMIT TRANSACTION;
   ''')
#close out the connection
c.close()
conn.close()
